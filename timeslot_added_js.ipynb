# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Jamestown_0621_0824/final_version_js.csv')

# %%
# #Weekday = Monday - Thursday && Shift = A && Hour = Slot 1 => Hour = 1:00;
#                                           Hour = Slot 2 => Hour = 2:00
#                                           Hour = sLOT 3 => Hour = 3:00
#                                           Hour = Slot 4 => Hour = 4:00
#                                           Hour = Slot 5 => Hour = 5:20
#                                           Hour = Slot 6 => Hour = 6:05
#                                           Hour = Slot 7 => Hour = 6:55
#                                           Hour = Slot 8 => Hour = 7:45
#                                           Hour = Slot 9 => Hour = 8:35
#                                           Hour = Slot 10 => Hour = 9:30
#                                           Hour = Slot 11 => delete row
#                                           Hour = Slot 12 => delete row

# #Weekday = Monday - Thursday && Shift B && Hour = Slot 1 => Hour = 5:00;
#                                           Hour = Slot 2 => Hour = 5:40
#                                           Hour = sLOT 3 => Hour = 6:30
#                                           Hour = Slot 4 => Hour = 7:20
#                                           Hour = Slot 5 => Hour = 8:10
#                                           Hour = Slot 6 => Hour = 9:00
#                                           Hour = Slot 7 => Hour = 10:00
#                                           Hour = Slot 8 => Hour = 11:00
#                                           Hour = Slot 9 => Hour = 12:00
#                                           Hour = Slot 10 => Hour = 13:00
#                                           Hour = Slot 11 => Hour = 14:00
#                                           Hour = Slot 12 => delete row

# #Weekday = Monday - Thursday && Shift C && Hour = Slot 1 => Hour = 10:30;
#                                           Hour = Slot 2 => Hour = 11:30
#                                           Hour = Slot 3 => Hour = 12:30
#                                           Hour = Slot 4 => Hour = 13:30
#                                           Hour = Slot 5 => Hour = 14:30
#                                           Hour = Slot 6 => Hour = 15:30
#                                           Hour = Slot 7 => Hour = 16:20
#                                           Hour = Slot 8 => Hour = 17:10
#                                           Hour = Slot 9 => Hour = 18:00
#                                           Hour = Slot 10 => Hour = 18:50
#                                           Hour = Slot 11 => Hour = 19:35
#                                           Hour = Slot 12 => delete row

# #Weekday = Monday - Thursday && Shift D && Hour = Slot 1 => Hour = 15:00;
#                                           Hour = Slot 2 => Hour = 15:55
#                                           Hour = sLOT 3 => Hour = 16:45
#                                           Hour = Slot 4 => Hour = 17:35
#                                           Hour = Slot 5 => Hour = 18:25
#                                           Hour = Slot 6 => Hour = 19:15
#                                           Hour = Slot 7 => Hour = 20:00
#                                           Hour = Slot 8 => Hour = 21:00
#                                           Hour = Slot 9 => Hour = 22:00
#                                           Hour = Slot 10 => Hour = 23:00
#                                           Hour = Slot 11 => Hour = 00:00
#                                           Hour = Slot 12 => delete row

# #Weekday = Monday - Thursday && Shift E && Hour = Slot 1 => delete row;
#                                           Hour = Slot 2 => Hour = 12:40
#                                           Hour = sLOT 3 => Hour = 13:40
#                                           Hour = Slot 4 => Hour = 14:40
#                                           Hour = Slot 5 => Hour = 15:40
#                                           Hour = Slot 6 => Hour = 16:40
#                                           Hour = Slot 7 => Hour = 17:40
#                                           Hour = Slot 8 => Hour = 18:40
#                                           Hour = Slot 9 => Hour = 19:30
#                                           Hour = Slot 10 => Hour = 20:30
#                                           Hour = Slot 11 => Hour = 21:30
#                                           Hour = Slot 12 => Hour = 22:30


# #Weekday = Friday - Sunday && Shift = C && Hour = Slot 1 => Hour = 10:30;
#                                           Hour = Slot 2 => Hour = 11:30
#                                           Hour = Slot 3 => Hour = 12:30
#                                           Hour = Slot 4 => Hour = 13:20
#                                           Hour = Slot 5 => Hour = 14:20
#                                           Hour = Slot 6 => Hour = 15:20
#                                           Hour = Slot 7 => Hour = 16:20
#                                           Hour = Slot 8 => Hour = 17:20
#                                           Hour = Slot 9 => Hour = 18:20
#                                           Hour = Slot 10 => Hour = 19:20
#                                           Hour = Slot 11 => delete row
#                                           Hour = Slot 12 => delete row

# #Weekday = Friday - Sunday && Shift = D && Hour = Slot 1 => Hour = 15:00;
#                                           Hour = Slot 2 => Hour = 16:00
#                                           Hour = Slot 3 => Hour = 17:00
#                                           Hour = Slot 4 => Hour = 18:00
#                                           Hour = Slot 5 => Hour = 19:00
#                                           Hour = Slot 6 => Hour = 20:00
#                                           Hour = Slot 7 => Hour = 21:00
#                                           Hour = Slot 8 => Hour = 22:00
#                                           Hour = Slot 9 => Hour = 23:00
#                                           Hour = Slot 10 => Hour = 0:00
#                                           Hour = Slot 11 => delete row
#                                           Hour = Slot 12 => delete row

# %%
# Mapping rules
time_mapping = {
    "A": {
        "Slot 1": "1:00", "Slot 2": "2:00", "Slot 3": "3:00", "Slot 4": "4:00",
        "Slot 5": "5:20", "Slot 6": "6:05", "Slot 7": "6:55", "Slot 8": "7:45",
        "Slot 9": "8:35", "Slot 10": "9:30", "Slot 11": None, "Slot 12": None
    },
    "B": {
        "Slot 1": "5:00", "Slot 2": "5:40", "Slot 3": "6:30", "Slot 4": "7:20",
        "Slot 5": "8:10", "Slot 6": "9:00", "Slot 7": "10:00", "Slot 8": "11:00",
        "Slot 9": "12:00", "Slot 10": "13:00", "Slot 11": "14:00", "Slot 12": None
    },
    "C": {
        "Slot 1": "10:30", "Slot 2": "11:30", "Slot 3": "12:30", "Slot 4": "13:30",
        "Slot 5": "14:30", "Slot 6": "15:30", "Slot 7": "16:20", "Slot 8": "17:10",
        "Slot 9": "18:00", "Slot 10": "18:50", "Slot 11": "19:35", "Slot 12": None
    },
    "D": {
        "Slot 1": "15:00", "Slot 2": "15:55", "Slot 3": "16:45", "Slot 4": "17:35",
        "Slot 5": "18:25", "Slot 6": "19:15", "Slot 7": "20:00", "Slot 8": "21:00",
        "Slot 9": "22:00", "Slot 10": "23:00", "Slot 11": "00:00", "Slot 12": None
    },
    "E": {
        "Slot 1": None, "Slot 2": "12:40", "Slot 3": "13:40", "Slot 4": "14:40",
        "Slot 5": "15:40", "Slot 6": "16:40", "Slot 7": "17:40", "Slot 8": "18:40",
        "Slot 9": "19:30", "Slot 10": "20:30", "Slot 11": "21:30", "Slot 12": "22:30"
    }
}

# Function to map times based on Shift
def map_hour(row):
    if row['Weekday'] in ["Monday", "Tuesday", "Wednesday", "Thursday"]:
        shift = row['Shift']
        slot = row['Hour']
        return time_mapping.get(shift, {}).get(slot)
    return row['Hour']  # Keep the original value for non-Monday-Thursday

# Apply the transformation
df['Hour'] = df.apply(map_hour, axis=1)

# Drop rows where Hour is None (e.g., marked for deletion)
# df.dropna(subset=['Hour'], inplace=True)

df.head(50)
# Out:
#     Unnamed: 0        Date  Weekday Shift   Hour  TOTAL  TRAILER  BUS  TRUCK  \
# 0            0  2021-06-01  Tuesday     A   1:00    1.0        0    0      0
# 1           33  2021-06-01  Tuesday     A   2:00    1.0        0    0      0
# 2           34  2021-06-01  Tuesday     A   3:00    2.0        0    0      0
# 3           35  2021-06-01  Tuesday     A   4:00   14.0        0    0      0
# 4           36  2021-06-01  Tuesday     A   5:20   17.0        0    0      0
# 5           37  2021-06-01  Tuesday     A   6:05   32.0        0    0      4
# 6           38  2021-06-01  Tuesday     A   6:55   45.0        0    0      5
# 7           39  2021-06-01  Tuesday     A   7:45   27.0        1    0      3
# 8           46  2021-06-01  Tuesday     A   8:35   29.0        1    0      2
# 9           40  2021-06-01  Tuesday     A   9:30   49.0        2    0      3
# 10          41  2021-06-01  Tuesday     A   None    0.0        0    0      0
# ...

# %%
# Mapping rules
time_mapping = {
    "A": {
        "Slot 1": "1:00", "Slot 2": "2:00", "Slot 3": "3:00", "Slot 4": "4:00",
        "Slot 5": "5:20", "Slot 6": "6:05", "Slot 7": "6:55", "Slot 8": "7:45",
        "Slot 9": "8:35", "Slot 10": "9:30", "Slot 11": None, "Slot 12": None
    },
    "B": {
        "Slot 1": "5:00", "Slot 2": "5:40", "Slot 3": "6:30", "Slot 4": "7:20",
        "Slot 5": "8:10", "Slot 6": "9:00", "Slot 7": "10:00", "Slot 8": "11:00",
        "Slot 9": "12:00", "Slot 10": "13:00", "Slot 11": "14:00", "Slot 12": None
    },
    "C": {
        "Slot 1": "10:30", "Slot 2": "11:30", "Slot 3": "12:30", "Slot 4": "13:20",
        "Slot 5": "14:20", "Slot 6": "15:20", "Slot 7": "16:20", "Slot 8": "17:20",
        "Slot 9": "18:20", "Slot 10": "19:20", "Slot 11": None, "Slot 12": None
    },
    "D": {
        "Slot 1": "15:00", "Slot 2": "16:00", "Slot 3": "17:00", "Slot 4": "18:00",
        "Slot 5": "19:00", "Slot 6": "20:00", "Slot 7": "21:00", "Slot 8": "22:00",
        "Slot 9": "23:00", "Slot 10": "0:00", "Slot 11": None, "Slot 12": None
    },
    "E": {
        "Slot 1": None, "Slot 2": "12:40", "Slot 3": "13:40", "Slot 4": "14:40",
        "Slot 5": "15:40", "Slot 6": "16:40", "Slot 7": "17:40", "Slot 8": "18:40",
        "Slot 9": "19:30", "Slot 10": "20:30", "Slot 11": "21:30", "Slot 12": "22:30"
    }
}

# Function to map times based on Shift
def map_hour(row):
    if row['Weekday'] in ["Friday", "Saturday", "Sunday"]:
        shift = row['Shift']
        slot = row['Hour']
        return time_mapping.get(shift, {}).get(slot)
    return row['Hour']  # Keep the original value for non-Monday-Thursday

# Apply the transformation
df['Hour'] = df.apply(map_hour, axis=1)

# Drop rows where Hour is None (e.g., marked for deletion)
# df.dropna(subset=['Hour'], inplace=True)

df.head(1000)
# Out:
#      Unnamed: 0        Date   Weekday Shift   Hour  TOTAL  TRAILER  BUS  \
# 0             0  2021-06-01   Tuesday     A   1:00    1.0        0    0
# 1            33  2021-06-01   Tuesday     A   2:00    1.0        0    0
# 2            34  2021-06-01   Tuesday     A   3:00    2.0        0    0
# 3            35  2021-06-01   Tuesday     A   4:00   14.0        0    0
# 4            36  2021-06-01   Tuesday     A   5:20   17.0        0    0
# ..          ...         ...       ...   ...    ...    ...      ...  ...
# 995         967  2021-06-17  Thursday     C   None    0.0        0    0
# 996         966  2021-06-17  Thursday     D  15:00   45.0        0    0
# 997         971  2021-06-17  Thursday     D  15:55   42.0        1    0
# 998         964  2021-06-17  Thursday     D  16:45   39.0        2    0
# 999         960  2021-06-17  Thursday     D  17:35   40.0        2    0
#
#      TRUCK  PED/BYC  LOD        Clouds: Precipitation:       Wind:  \
# ...

# %%
# Drop rows where Hour is None (e.g., marked for deletion)
df.dropna(subset=['Hour'], inplace=True)

df.head(1000)
# Out:
#       Unnamed: 0        Date   Weekday Shift   Hour  TOTAL  TRAILER  BUS  \
# 0              0  2021-06-01   Tuesday     A   1:00    1.0        0    0
# 1             33  2021-06-01   Tuesday     A   2:00    1.0        0    0
# 2             34  2021-06-01   Tuesday     A   3:00    2.0        0    0
# 3             35  2021-06-01   Tuesday     A   4:00   14.0        0    0
# 4             36  2021-06-01   Tuesday     A   5:20   17.0        0    0
# ...          ...         ...       ...   ...    ...    ...      ...  ...
# 1122        1080  2021-06-19  Saturday     D  21:00   10.0        0    0
# 1123        1090  2021-06-19  Saturday     D  22:00   23.0        0    0
# 1124        1109  2021-06-19  Saturday     D  23:00   17.0        0    0
# 1125        1092  2021-06-19  Saturday     D   0:00   12.0        0    0
# 1129        1096  2021-06-19  Saturday     E  12:40   50.0        0    0
#
#       TRUCK  PED/BYC  LOD        Clouds: Precipitation:       Wind:  \
# ...

# %%
df.to_csv("/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Final_Dataset/Jamestown.csv")
