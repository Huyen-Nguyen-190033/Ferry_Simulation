# %%
import pandas as pd
import numpy as np
import os

# %%
# Specify the folder containing the CSV files
folder_path = '/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Scotland_0621_0824/Scotland_21'

# List to hold each DataFrame
dfs = []

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the CSV file into a DataFrame and add it to the list
        file_path = os.path.join(folder_path, file_name)
        dfs.append(pd.read_csv(file_path))

# Concatenate all DataFrames in the list into a single DataFrame
merged_df_21 = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
merged_df_21
# Out:
#        Unnamed: 0        Date  Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0  2021-06-01  Tuesday     A   Slot 1      1        0    0
# 1               1  2021-06-01  Tuesday     A   Slot 2      2        0    0
# 2               2  2021-06-01  Tuesday     A   Slot 3      6        0    0
# 3               3  2021-06-01  Tuesday     A   Slot 4     19        0    0
# 4               4  2021-06-01  Tuesday     A   Slot 5      8        0    0
# ...           ...         ...      ...   ...      ...    ...      ...  ...
# 11765        1700  2021-12-31   Friday     E   Slot 7      0        0    0
# 11766        1701  2021-12-31   Friday     E   Slot 8      0        0    0
# 11767        1702  2021-12-31   Friday     E   Slot 9      0        0    0
# 11768        1703  2021-12-31   Friday     E  Slot 10      0        0    0
# 11769        1704  2021-12-31   Friday     E  Slot 11      0        0    0
#
# ...

# %%
# Specify the folder containing the CSV files
folder_path = '/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Scotland_0621_0824/Scotland_22'

# List to hold each DataFrame
dfs = []

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the CSV file into a DataFrame and add it to the list
        file_path = os.path.join(folder_path, file_name)
        dfs.append(pd.read_csv(file_path))

# Concatenate all DataFrames in the list into a single DataFrame
merged_df_22 = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
merged_df_22
# Out:
#        Unnamed: 0        Date   Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0  2022-01-01  Saturday     A   Slot 1      4        0    0
# 1               1  2022-01-01  Saturday     A   Slot 2      4        0    0
# 2               2  2022-01-01  Saturday     A   Slot 3      4        0    0
# 3               3  2022-01-01  Saturday     A   Slot 4      3        0    0
# 4               4  2022-01-01  Saturday     A   Slot 5      3        0    0
# ...           ...         ...       ...   ...      ...    ...      ...  ...
# 20070        1700  2022-12-31  Saturday     E   Slot 7      0        0    0
# 20071        1701  2022-12-31  Saturday     E   Slot 8      0        0    0
# 20072        1702  2022-12-31  Saturday     E   Slot 9      0        0    0
# 20073        1703  2022-12-31  Saturday     E  Slot 10      0        0    0
# 20074        1704  2022-12-31  Saturday     E  Slot 11      0        0    0
#
# ...

# %%
# Specify the folder containing the CSV files
folder_path = '/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Scotland_0621_0824/Scotland_23'

# List to hold each DataFrame
dfs = []

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the CSV file into a DataFrame and add it to the list
        file_path = os.path.join(folder_path, file_name)
        dfs.append(pd.read_csv(file_path))

# Concatenate all DataFrames in the list into a single DataFrame
merged_df_23 = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
merged_df_23
# Out:
#        Unnamed: 0        Date Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0  2023-01-01  Sunday     A   Slot 1     11        0    0
# 1               1  2023-01-01  Sunday     A   Slot 2      3        0    0
# 2               2  2023-01-01  Sunday     A   Slot 3      3        0    0
# 3               3  2023-01-01  Sunday     A   Slot 4     10        0    0
# 4               4  2023-01-01  Sunday     A   Slot 5      1        0    0
# ...           ...         ...     ...   ...      ...    ...      ...  ...
# 20070        1700  2023-12-31  Sunday     E   Slot 7      0        0    0
# 20071        1701  2023-12-31  Sunday     E   Slot 8      0        0    0
# 20072        1702  2023-12-31  Sunday     E   Slot 9      0        0    0
# 20073        1703  2023-12-31  Sunday     E  Slot 10      0        0    0
# 20074        1704  2023-12-31  Sunday     E  Slot 11      0        0    0
#
#        TRUCK  PED/BYC  LOD        Clouds: Precipitation:          Wind:  \
# ...

# %%
# Specify the folder containing the CSV files
folder_path = '/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Scotland_0621_0824/Scotland_24'

# List to hold each DataFrame
dfs = []

# Loop through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the CSV file into a DataFrame and add it to the list
        file_path = os.path.join(folder_path, file_name)
        dfs.append(pd.read_csv(file_path))

# Concatenate all DataFrames in the list into a single DataFrame
merged_df_24 = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
merged_df_24
# Out:
#        Unnamed: 0        Date  Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0  2024-01-01   Monday     A   Slot 1   12.0        0    0
# 1               1  2024-01-01   Monday     A   Slot 2    2.0        0    0
# 2               2  2024-01-01   Monday     A   Slot 3    4.0        0    0
# 3               3  2024-01-01   Monday     A   Slot 4    2.0        0    0
# 4               4  2024-01-01   Monday     A   Slot 5    1.0        0    0
# ...           ...         ...      ...   ...      ...    ...      ...  ...
# 13415        1645  2024-04-30  Tuesday     E   Slot 7    0.0        0    0
# 13416        1646  2024-04-30  Tuesday     E   Slot 8    0.0        0    0
# 13417        1647  2024-04-30  Tuesday     E   Slot 9    0.0        0    0
# 13418        1648  2024-04-30  Tuesday     E  Slot 10    0.0        0    0
# 13419        1649  2024-04-30  Tuesday     E  Slot 11    0.0        0    0
#
# ...

# %%
# Concatenate all DataFrames in the list into a single DataFrame
merged_df_js = pd.concat([merged_df_21, merged_df_22, merged_df_23, merged_df_24], ignore_index=True)
merged_df_js
# Out:
#        Unnamed: 0        Date  Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0  2021-06-01  Tuesday     A   Slot 1    1.0        0    0
# 1               1  2021-06-01  Tuesday     A   Slot 2    2.0        0    0
# 2               2  2021-06-01  Tuesday     A   Slot 3    6.0        0    0
# 3               3  2021-06-01  Tuesday     A   Slot 4   19.0        0    0
# 4               4  2021-06-01  Tuesday     A   Slot 5    8.0        0    0
# ...           ...         ...      ...   ...      ...    ...      ...  ...
# 65335        1645  2024-04-30  Tuesday     E   Slot 7    0.0        0    0
# 65336        1646  2024-04-30  Tuesday     E   Slot 8    0.0        0    0
# 65337        1647  2024-04-30  Tuesday     E   Slot 9    0.0        0    0
# 65338        1648  2024-04-30  Tuesday     E  Slot 10    0.0        0    0
# 65339        1649  2024-04-30  Tuesday     E  Slot 11    0.0        0    0
#
# ...

# %%
# Ensure the 'date' column is in datetime format
merged_df_js['Date'] = pd.to_datetime(merged_df_js['Date'])

# Sort the DataFrame by the 'date' column
merged_df_js = merged_df_js.sort_values(by='Date')

# Display the sorted DataFrame
merged_df_js
# Out:
#        Unnamed: 0       Date   Weekday Shift     Hour  TOTAL  TRAILER  BUS  \
# 0               0 2021-06-01   Tuesday     A   Slot 1    1.0        0    0
# 30             30 2021-06-01   Tuesday     C   Slot 9   45.0        1    0
# 31             31 2021-06-01   Tuesday     C  Slot 10   21.0        1    0
# 32             32 2021-06-01   Tuesday     C  Slot 11   22.0        0    0
# 33             33 2021-06-01   Tuesday     D   Slot 1   44.0        0    0
# ...           ...        ...       ...   ...      ...    ...      ...  ...
# 63657        1672 2024-08-31  Saturday     C   Slot 1   41.0        2    0
# 63658        1673 2024-08-31  Saturday     C   Slot 2   33.0        0    0
# 63659        1674 2024-08-31  Saturday     C   Slot 3   48.0        0    0
# 63661        1676 2024-08-31  Saturday     C   Slot 5   24.0        1    0
# 63688        1703 2024-08-31  Saturday     E  Slot 10    0.0        0    0
#
# ...

# %%
# Count occurrences of each date
date_counts = merged_df_js['Date'].value_counts()

# Filter dates that appear more than 60 times
dates_more_than_60 = date_counts[date_counts > 55]

# Display the results
dates_more_than_60
# Out:
# Series([], Name: count, dtype: int64)

# %%
merged_df_js.to_csv('/content/drive/MyDrive/Sim_FinalProject_FerryTraffic/Huyen/Clean_Data/Scotland_0621_0824/sc_total.csv')
